# %% [markdown]
# # **Matplotlib**

# %% [markdown]
# Es la base para aprender visualizacion de datos aunque haya bibliotecas más sofisticadas

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Conceptos basicos
# ### Arquitectura

# %%
#Datos de ejemplo

x= np.linspace(0,10,100)
y = np.sin(x)
y2 = np.cos(x)

# %%
fig = plt.figure (figsize = (10,6))
#la priera linea determina el tamanio del grafico
ax = fig.add_subplot(1 , 1 , 1)
#Axes es el area del grafico, los axes se agregan a la figure(dodne se van a ;dibujar)
ax.set_xlim(0,10)
ax.set_ylim(-1.5, 1.5)
#Estios son los ejes controlan el rango y las etiquetas
line, = ax.plot(x, y, label = 'Seno', color = 'green')
text = ax.text(2, np.sin(2), 'Punto', fontsize = 12, color = 'red')#Aca van los elementos graficos
ax.legend()
plt.show()

# %% [markdown]
# ### Estilos

# %%
#Imprimimos una liste de estilos disponibles en matplotlib
print("Estilos disponibles:", plt.style.available)
plt.style.use('ggplot') #Elegimos un estilo de los  disponibles
fig, ax = plt.subplots(figsize = (10,6))
ax.plot(x,y, label = 'Seno', color = "blue")
ax.plot(x, y2, label = 'Coseno', color = 'red')
ax.set_title('grafico de Seno y coseno con estilo seaborn -darkgrid')
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.legend()
plt.show()
# Out:
# Estilos disponibles: ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#Imprimimos una liste de estilos disponibles en matplotlib
print("Estilos disponibles:", plt.style.available)
plt.style.use('ggplot') #Elegimos un estilo de los  disponibles
fig, ax = plt.subplots(figsize = (10,6))
#ax = fig.add_subplot(1 , 1 , 1)
#Axes es el area del grafico, los axes se agregan a la figure(dodne se van a ;dibujar)
#ax.set_xlim(0,10)
ax.set_ylim(-1.0, 1.0)
ax.plot(x,y, label = 'Seno', color = "green")
ax.plot(x, y2, label = 'Coseno', color = 'orange')
ax.set_facecolor('lightgrey')
ax.grid(True, linestyle = '--', color = 'grey', alpha = 0.7)
ax.set_title('grafico de Seno y coseno con estilo seaborn -darkgrid')
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.legend()
plt.show()
# Out:
# Estilos disponibles: ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ## Tipos de Graficos
# ### Barra

# %%
#Datos de ejemplo
x = np.linspace(0,10, 100)

y = np.sin(x)

# %% [markdown]
# Grafico de linea simple

# %% [markdown]
# #### Personalizacion
# cambiar colores y estilos de linea

# %%
plt.plot(x,y, color = 'purple', linestyle = ':', linewidth = 3)
plt.title('Grafico de linea personalizado')
plt.xlabel('Eje X')
plt.ylabel('Eje y')
plt.show()

# %% [markdown]
# Graficos de lineas avanzados
# Multiples lineas en un solo grafico

# %%
y2 = np.cos(x)

plt.plot(x,y, label = "Seno", color = 'purple', linestyle = ':', linewidth = 3)
plt.plot(x,y2, label = "Coseno", color = 'green', linestyle = ':', linewidth = 3)
plt.title('Grafico con multiples lineas')
plt.xlabel('Eje X')
plt.ylabel('Eje y')
plt.legend()
plt.show()
